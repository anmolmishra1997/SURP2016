# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("C:\Users\Anmol Mishra\Desktop\SURP\compucell3d\Demo.cc3d-2016-04-27-15-08-16-571000\data.csv")

# %%
df2 = pd.read_csv("C:\Users\Anmol Mishra\Desktop\SURP\compucell3d\Demo.cc3d-2016-04-27-16-27-03-550000\data.csv")

# %%
df3 = pd.read_csv("C:\Users\Anmol Mishra\Desktop\SURP\compucell3d\Demo.cc3d-2016-04-27-15-10-44-660000\data.csv")

# %%
df1_plot = df1[df1['MCS'] == 499]
df2_plot = df2[df2['MCS'] == 699]
df3_plot = df3[df3['MCS'] == 999]

# %%
df1_plot.plot.hist(y='Volume',bins=20)

# %%
df2_plot.plot.hist(y='Volume',bins =20)

# %%
df3_plot.plot.hist(y='Volume', bins =20)
